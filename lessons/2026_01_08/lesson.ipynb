# %%
def my_range_gen(n):
    counter = 0
    while counter < n:
        yield counter  # Здесь функция "замирает" и возвращает значение
        counter += 1

# %%
# через next
gen = my_range_gen(3) # Создается объект-генератор, код НЕ выполняется.
print(next(gen)) # Выполняется до первого yield, возвращает 0
print(next(gen)) # Продолжает с места остановки, возвращает 1
print(next(gen)) # Продолжает, возвращает 2
# Out:
# 0
# 1
# 2

# %%
# через for
for i in my_range_gen(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
def my_range_gen(n):
    counter = 0
    while counter < n:
        yield counter  # Здесь функция "замирает" и возвращает значение
        counter += 1

gen = my_range_gen(3) # Создается объект-генератор, код НЕ выполняется.
print(next(gen)) # Выполняется до первого yield, возвращает 0
print(next(gen)) # Продолжает с места остановки, возвращает 1
print(next(gen)) # Продолжает, возвращает 2
print(next(gen)) # -> StopIteration
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 11
#       9 print(next(gen)) # Продолжает с места остановки, возвращает 1
#      10 print(next(gen)) # Продолжает, возвращает 2
# ---> 11 print(next(gen)) # -> StopIteration
#
# StopIteration:

# %%
def my_range_gen(n):
    counter = 0
    while counter < n:
        yield counter  # Здесь функция "замирает" и возвращает значение
        counter += 1

    while True:
        yield 'finish'

gen = my_range_gen(3) # Создается объект-генератор, код НЕ выполняется.
print(next(gen)) # Выполняется до первого yield, возвращает 0
print(next(gen)) # Продолжает с места остановки, возвращает 1
print(next(gen)) # Продолжает, возвращает 2
print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 0
# 1
# 2
# finish
# finish
# finish
# finish
